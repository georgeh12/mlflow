# %% [markdown]
# # Test file

# %% [markdown]
# ## Imports

# %%
# MLflow
import mlflow
from mlflow.models import infer_signature

# MLflow model
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Visualizations
import matplotlib.pyplot as plt

# math functions
import numpy as np

# read CSV file
import os
import glob

# data frames
import pandas as pd

# regexes
import re

# %% [markdown]
# ## Load training data

# %%
# future warnings
import warnings
warnings.filterwarnings("ignore")

# Use the Kickstarter dataset
"""
    ['backers_count', 'blurb', 'category', 'converted_pledged_amount', 'country', 'country_displayable_name', 
    'created_at', 'creator', 'currency', 'currency_symbol', 'currency_trailing_code', 'current_currency', 'deadline', 
    'disable_communication', 'fx_rate', 'goal', 'id', 'is_disliked', 'is_launched', 'is_liked', 'is_starrable', 
    'launched_at', 'location', 'name', 'percent_funded', 'photo', 'pledged', 'prelaunch_activated', 'profile', 
    'slug', 'source_url', 'spotlight', 'staff_pick', 'state', 'state_changed_at', 'static_usd_rate', 'urls', 
    'usd_exchange_rate', 'usd_pledged', 'usd_type', 'video']
"""
df = pd.DataFrame()
df_files = {}
running_total = 0
for fname in glob.glob(os.path.abspath('./data/**/*.csv')):
    _df=pd.read_csv(fname)
    df = df.append(_df.copy(), ignore_index=True)
    df_files[os.path.basename(fname)] = _df
    running_total+=len(_df)
    print(fname)
    print(running_total)
    #break #DEBUG

# US-only, because keywords are in English
"""
df = df[df['country'] == 'US']
print(len(df))
df = df[df['category'].str.contains('"parent_name":"Technology"')]
print(len(df))
"""

# List of regular expressions for search terms
search_terms = []
search_acronyms = ['ai','ml','nlp']
search_words = ['artificial intelligence', 'neural networks', 'computer vision', 'natural language processing', 'deep learning',
                'Tensorflow','robotics', 'chatbot', 'Augmented Reality', 'Speech Generation']
for term in search_acronyms:
    pattern = r'[ (]' + ''.join([f'{char}[.]?' for char in term]) + r'[ ,.)]'
    search_terms.append(pattern)
for term in search_words:
    pattern = re.sub(r'(\s|-)', r'[ -]?', term)
    search_terms.append(pattern)
regex_patterns = [re.compile(term, re.IGNORECASE) for term in search_terms]

# building ai_mention field
search_columns = ['blurb','name']
for column in search_columns:
    df['ai_matches_' + column] = df[column].apply(lambda text: [pattern.search(str(text).lower()).group() for pattern in regex_patterns if pattern.search(str(text).lower())] or None)
    df['ai_mention_' + column] = df['ai_matches_' + column].apply(lambda x: x is not None)
df['ai_mention'] = df[['ai_mention_' + column for column in search_columns]].any(axis=1)
# Out:
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-01-05T03_20_04_136Z\Kickstarter.csv
# 3659
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-01-05T03_20_04_136Z\Kickstarter001.csv
# 7349
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-01-05T03_20_04_136Z\Kickstarter002.csv
# 7432
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-02-16T03_20_05_221Z\Kickstarter.csv
# 11078
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-02-16T03_20_05_221Z\Kickstarter001.csv
# 11825
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-03-09T03_20_04_199Z\Kickstarter.csv
# 15405
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-04-18T13_03_17_223Z\Kickstarter.csv
# 19045
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-04-18T13_03_17_223Z\Kickstarter001.csv
# 22739
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-04-18T13_03_17_223Z\Kickstarter002.csv
# 26425
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-04-18T13_03_17_223Z\Kickstarter003.csv
# 30085
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-04-18T13_03_17_223Z\Kickstarter004.csv
# 33724
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-04-18T13_03_17_223Z\Kickstarter005.csv
# 35048
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter018.csv
# 401381
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter019.csv
# 405047
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter020.csv
# 408707
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter021.csv
# 412374
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter022.csv
# 416043
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter023.csv
# 419698
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter024.csv
# 423366
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter025.csv
# 427032
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter026.csv
# 430697
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter027.csv
# 434362
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter028.csv
# 438029
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter029.csv
# 441692
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter030.csv
# 445356
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter031.csv
# 449022
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter032.csv
# 452685
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter033.csv
# 456345
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter034.csv
# 460009
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter035.csv
# 463679
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter036.csv
# 467334
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter037.csv
# 471001
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter038.csv
# 474668
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter039.csv
# 478336
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter040.csv
# 481997
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter041.csv
# 485660
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter042.csv
# 489323
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter043.csv
# 492991
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter044.csv
# 496648
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter045.csv
# 500316
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter046.csv
# 503979
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter047.csv
# 507644
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter048.csv
# 511314
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter049.csv
# 514972
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter050.csv
# 518639
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter051.csv
# 522304
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter052.csv
# 525972
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter053.csv
# 529632
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter054.csv
# 533297
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter055.csv
# 536966
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter056.csv
# 540626
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter057.csv
# 544286
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter058.csv
# 547953
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter059.csv
# 551615
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter060.csv
# 555278
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter061.csv
# 558951
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter062.csv
# 562612
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter063.csv
# 566278
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter064.csv
# 569944
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-10-12T03_20_02_365Z\Kickstarter065.csv
# 572246
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-11-16T03_20_10_045Z\Kickstarter.csv
# 575935
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-11-16T03_20_10_045Z\Kickstarter001.csv
# 579617
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-11-16T03_20_10_045Z\Kickstarter002.csv
# 583277
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-11-16T03_20_10_045Z\Kickstarter003.csv
# 586965
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-11-16T03_20_10_045Z\Kickstarter004.csv
# 590650
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-11-16T03_20_10_045Z\Kickstarter005.csv
# 594317
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-11-16T03_20_10_045Z\Kickstarter006.csv
# 597526
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter.csv
# 600839
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter001.csv
# 604177
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter002.csv
# 607508
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter003.csv
# 610849
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter004.csv
# 614218
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter005.csv
# 617533
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter006.csv
# 620863
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2023-12-14T03_20_06_766Z\Kickstarter007.csv
# 622438
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter.csv
# 625760
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter001.csv
# 629069
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter002.csv
# 632405
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter003.csv
# 635728
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter004.csv
# 639077
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter005.csv
# 642435
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter006.csv
# 645796
# c:\Users\georg\Documents\GitHub\mlflow\data\Kickstarter_2024-01-15T14_13_05_649Z\Kickstarter007.csv
# 648395

# %%
# Debugging
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)
#df.info()
total = len(df.index)
ai_mentions = df.loc[df['ai_mention'] == True].shape[0]
print(f"{ai_mentions}(ai_mentions)/{total}(total) = {ai_mentions/total}")
#df.loc[df['ai_mention_blurb'] == True, ['name', 'blurb', 'ai_mention', 'ai_matches_blurb', 'ai_matches_name']]
df.describe()
# Out:
# 332(ai_mentions)/50869(total) = 0.006526568243920659
#        backers_count  converted_pledged_amount    created_at      deadline       fx_rate          goal            id   launched_at       pledged  state_changed_at  static_usd_rate  usd_exchange_rate   usd_pledged  percent_funded
# count   50869.000000              4.914400e+04  5.086900e+04  5.086900e+04  50869.000000  5.086900e+04  5.086900e+04  5.086900e+04  5.086900e+04      5.086900e+04     50869.000000       49144.000000  4.914400e+04    50869.000000
# mean      156.517761              1.775678e+04  1.542898e+09  1.500250e+09      0.964297  8.198905e+04  1.071569e+09  1.491441e+09  3.952650e+04      1.550347e+09         0.948708           0.981565  1.774761e+04      391.698381
# std      1340.065802              2.841367e+05  1.095685e+08  2.862818e+08      0.246495  6.334846e+06  6.199065e+08  2.994500e+08  6.090853e+05      1.097571e+08         0.313304           0.262125  2.839954e+05     7539.281301
# min         0.000000              0.000000e+00  1.240456e+09  0.000000e+00      0.006864  0.000000e+00  4.813900e+04  0.000000e+00  0.000000e+00      1.242468e+09         0.000000           0.006607  0.000000e+00        0.000000
# 25%         5.000000              2.340000e+02  1.450569e+09  1.445722e+09      1.000000  1.300000e+03  5.345001e+08  1.441823e+09  1.560000e+02      1.458416e+09         1.000000           1.000000  2.349372e+02        3.588235
# 50%        31.000000              2.361500e+03  1.551320e+09  1.545541e+09      1.000000  5.000000e+03  1.072753e+09  1.540915e+09  2.205000e+03      1.558962e+09         1.000000           1.000000  2.363070e+03      103.577778
# 75%       101.000000              9.541000e+03  1.645280e+09  1.646599e+09      1.000000  1.500000e+04  1.611964e+09  1.643050e+09  1.013100e+04      1.653671e+09         1.000000           1.000000  9.560000e+03      139.714286
# max    185341.000000              4.175415e+07  1.705279e+09  1.710511e+09      1.275463  1.000000e+09  2.147437e+09  1.705328e+09  6.100265e+07      1.705328e+09         1.715913           1.716408  4.175415e+07   655800.000000

# %%
# Convert all numeric columns to numeric type
numeric_columns = df.select_dtypes(include='number').columns
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Remove NA items
df.replace([np.inf, -np.inf], np.nan, inplace=True)
feature_names = ['backers_count','spotlight','staff_pick','percent_funded', 'is_disliked', 'is_launched', 'is_liked', 'is_starrable', 'goal']
df.dropna(subset=feature_names, how="any", inplace=True)
target_name = 'ai_mention'
df.dropna(subset=target_name, how="any", inplace=True)
X = df.loc[:, df.columns[:,None] == feature_names]
y = df.loc[:, df.columns == target_name].values
print(f"{ai_mentions}(ai_mentions)/{total}(total) = {ai_mentions/total}")
# Out:
# 3669(ai_mentions)/648395(total) = 0.00565858774358223

# %%
# MLflow model
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer as imp

# Enable automatic logging to MLflow
mlflow.set_experiment("MLflow")
mlflow.autolog()

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

rf_params = {'n_estimators':100, 'max_depth':6, 'max_features':3}
logr_params = {}
lr_params = {}

# Train the model
rf = RandomForestRegressor(**rf_params)

# MLflow triggers logging automatically upon model fitting
rf.fit(X_train, y_train)

# Predict on the test set
rf_y_pred = rf.predict(X_test)

logr = LogisticRegression(**logr_params)

# MLflow triggers logging automatically upon model fitting
logr.fit(X_train, y_train)

# Predict on the test set
logr_y_pred = logr.predict(X_test)

lr = LinearRegression(**lr_params)

# MLflow triggers logging automatically upon model fitting
lr.fit(X_train, y_train)

# Predict on the test set
lr_y_pred = lr.predict(X_test)
# Out:
# 2024/02/16 15:04:30 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/02/16 15:04:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5c290a56edd84fd4b8c09abfc0c82ceb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/02/16 15:04:39 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'eddfbac78e7f43b19a9813dfd9400608', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/02/16 15:04:39 WARNING mlflow.sklearn.utils: Failed to autolog artifacts for LogisticRegression. Logging error: unhashable type: 'numpy.ndarray'
# 2024/02/16 15:04:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0746a6e3e0c6469c986d1c837984bef3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %% [markdown]
# ## Random Forest

# %%
from sklearn import tree
fn=X_train.columns
cn=target_name
fig, axes = plt.subplots(nrows = 1,ncols = 5,figsize = (10,2), dpi=900)
for index in range(0, 5):
    tree.plot_tree(rf.estimators_[index],
        feature_names = fn,
        class_names=cn,
        filled = True,
        ax = axes[index])
    axes[index].set_title('Estimator: ' + str(index), fontsize = 11)

fig, axes = plt.subplots(nrows = 1,ncols = 5,figsize = (10,2), dpi=900)
next = 5
for index in range(0+next, 5+next):
    axes_idx = index - next
    tree.plot_tree(rf.estimators_[index],
        feature_names = fn,
        class_names=cn,
        filled = True,
        ax = axes[axes_idx])
    axes[axes_idx].set_title('Estimator: ' + str(index), fontsize = 11)

# %%
accuracy = mean_absolute_error(y_test, rf_y_pred)
print(accuracy)
#plt.scatter(X_train, y_train, color='red')
plt.plot(X_test, rf_y_pred, color='blue', linewidth=3)
plt.xlabel('Regressors')
plt.ylabel('AI mention')
plt.title('Random Forest - Regressors vs. AI mention')
plt.show()
# Out:
# 0.012549335232795587

# %% [markdown]
# ## Logistic Regression

# %%
X_train[feature_names]
# Out:
#         backers_count  spotlight  staff_pick  percent_funded is_disliked is_launched is_liked  is_starrable    goal
# 601924             31       True       False      100.925926       False        True    False         False  2700.0
# ...               ...        ...         ...             ...         ...         ...      ...           ...     ...
# 600258              6      False       False        8.108108       False        True    False         False  3700.0
#
# [25434 rows x 9 columns]

# %%
logr.coef_
# Out:
# array([[ 9.91962692e-06,  2.97211215e-09, -3.39577244e-01,
#         -4.44032463e-01, -3.87548496e-02,  0.00000000e+00,
#         -2.36819125e+00,  0.00000000e+00,  4.39106556e-06]])

# %%
logr_coefficients = logr.coef_[0]  # Obtain the coefficients

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.barh(range(len(logr_coefficients)), logr_coefficients, color='skyblue')
# Add labels to the bars
for i, coef in enumerate(logr_coefficients):
    plt.text(coef, i, f'{coef:.2f}', ha='left', va='center', color='black', fontsize=10)

# Set y-axis labels and ticks
plt.yticks(range(len(feature_names)), feature_names)

plt.xlabel('Coefficient Value')
plt.title('Regression Coefficients')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Add grid lines for better readability
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Plot the scatter plot of the training data along with the fitted values for each feature
num_features = X_train.shape[1]
fig, axes = plt.subplots(nrows=1, ncols=num_features, figsize=(15, 4))  # Adjust figsize as needed

for i in range(num_features):
    feature_name = X_train.columns[i]
    axes[i].scatter(X_train.iloc[:, i], y_train, color='red', label='Training Data')
    axes[i].scatter(X_test.iloc[:, i], lr_y_pred, color='blue', label='Fitted Values')
    axes[i].set_xlabel(feature_name)
    axes[i].set_ylabel('AI mention')
    axes[i].set_title(f'{feature_name}')
    axes[i].legend()

plt.tight_layout()
plt.show()
